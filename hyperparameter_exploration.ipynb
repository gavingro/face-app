# %%
import logging
import sys

import torch
from torchinfo import summary
import matplotlib.pyplot as plt

from src.resnetregressor import ResNetRegressor
from src.data import train_loader, test_loader, validation_loader
from src.data import dummy_train, dummy_validation, dummy_test
from src.current_model import model

# %% [markdown]
# ---
#
# # Dummy Model

# %%
dummy_model = ResNetRegressor()
# Out:
# Using cache found in /Users/gavin/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
dummy_model.fit(dummy_train, dummy_validation, num_epochs=5, model_name="dummy_resnet", save_every=500)
# Out:
# === Epoch 1 / 5 ===
# epoch_training_loss=33.054704666137695,	 epoch_validation_loss=9.391253471374512
# === Epoch 2 / 5 ===
# epoch_training_loss=32.958942890167236,	 epoch_validation_loss=9.352425575256348
# === Epoch 3 / 5 ===
# epoch_training_loss=32.92480230331421,	 epoch_validation_loss=9.341849327087402
# === Epoch 4 / 5 ===
# epoch_training_loss=32.86230230331421,	 epoch_validation_loss=9.31946086883545
# === Epoch 5 / 5 ===
# epoch_training_loss=32.82795524597168,	 epoch_validation_loss=9.26492691040039
# ([33.054704666137695,
#   32.958942890167236,
#   32.92480230331421,
#   32.86230230331421,
#   32.82795524597168],
#  [9.391253471374512,
#   9.352425575256348,
#   9.341849327087402,
#   9.31946086883545,
#   9.26492691040039])

# %%
# LEARNING_RATE = 0.00012
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.5
#dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00011
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.3
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# RESNET 34
# LEARNING_RATE = 0.0001
# L2_DECAY_RATE = 0.0
# DROPOUT_RATE = 0.3
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# RESNET 34
# LEARNING_RATE = 0.0001
# L2_DECAY_RATE = 0.0
# DROPOUT_RATE = 0.01
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
#34
# LEARNING_RATE = 0.0001
# L2_DECAY_RATE = 0.0005
# DROPOUT_RATE = 0.4
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00009
# L2_DECAY_RATE = 0.0004
# DROPOUT_RATE = 0.4
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
#34
# LEARNING_RATE = 0.0001
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.4
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING RATE = 0.0001 DECAY 0, DROPOUT 0.5
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00008
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.5
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00005
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.5
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00008
# L2_DECAY_RATE = 0.001
# DROPOUT_RATE = 0.5
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
# LEARNING_RATE = 0.00001
# L2_DECAY_RATE = 0.0001
# DROPOUT_RATE = 0.5
dummy_model.visualize_training()
# Out:
# <AxesSubplot:title={'center':'Training and Validation Loss vs Epochs'}>

# %%
logging.basicConfig(filename = "my.log", level=logging.INFO, stream=sys.stdout)
dummy_model = ResNetRegressor()
dummy_model.fit(dummy_train, dummy_test, save_every=1000)
dummy_model.score(dummy_train, dummy_test)
# Out:
# Using cache found in /Users/gavin/.cache/torch/hub/pytorch_vision_v0.10.0
